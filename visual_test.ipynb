# %%
import os
from supabase import create_client, Client

url = "url"
key = "key"
# 初始化客户端
supabase: Client = create_client(url, key)

# 1. 查询表里的所有比赛数据
response = (
    supabase.table("crs_match_info")
    .select("*")
    .execute()
)
print("所有数据:", response.data)
